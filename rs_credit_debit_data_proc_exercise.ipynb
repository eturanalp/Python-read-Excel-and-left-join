# %%
# OVERVIEW and APPROACH
# This python program separates the matched records from the unmatched ones after reading data from URL.
#
# I had two possible solutions in my mind. The first one was to iterate through the data set and 
# for each record identify if there is matching credit\debit. Write the record to the corresponding output file 
# depending on the condition. For examle, if there is not a matching credit for a debit record then write it to the 
# file for the unmatched.  
# The second approach which I decided to pursue is to use SQL-like features of Pandas\datasets. I used the merge() 
# function to make self-joins in order to match the credits to the debits on the specified fields.  
# This option was less robust\flexible compared to the first option but resulted in a more easily maintainable code.

# Author: Mehmet Emin Turanalp, 12/28/2017

#References\Resources:
#1. https://stackoverflow.com/questions/25685545/sql-how-to-return-rows-from-left-table-not-found-in-right-table
#2. http://nbviewer.jupyter.org/urls/bitbucket.org/hrojas/learn-pandas/raw/master/lessons/03%20-%20Lesson.ipynb
#3. https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_excel.html

# %%
import pandas as pd

# %%
url="https://s3-us-west-1.amazonaws.com/roofstock-test/data+assignment+dataset.xlsx"
df=pd.read_excel(url)

# %%
print('OK!')
# Out:
# OK!

# %%
df.dtypes
# Out:
# Property                 object
# Date             datetime64[ns]
# Payee / Payer            object
# Type                     object
# Reference                object
# Debit                   float64
# Credit                  float64
# Balance                 float64
# Description              object
# GL Account               object
# dtype: object

# %%
#dfs=df.query('Property == "1601 MADISON COURT PALATKA, FL 32177"')
dfs=df.copy()
print('data set size is', len(dfs))
# Out:
# data set size is 1225

# %%
# Assumption: all debit transactions are the ones with Debit not equal to null (same for credits)
dfs_all_debit=dfs[dfs['Debit'].notnull()]
dfs_all_credit=dfs[dfs['Credit'].notnull()]

# %%
# Join the Credits and Debits tables such that Credits.Credit==Debits.Debit and the other 5 fields are equal. 
# This is the list of matching debits and matching credits
dfs_debit=dfs_all_debit.merge(dfs_all_credit, right_on=('Property','Date','Payee / Payer','Type','Reference','Credit'), left_on=('Property','Date','Payee / Payer','Type','Reference','Debit'), how='inner')
dfs_credit=dfs_all_credit.merge(dfs_all_debit, right_on=('Property','Date','Payee / Payer','Type','Reference','Debit'), left_on=('Property','Date','Payee / Payer','Type','Reference','Credit'), how='inner')
dfs_credit
# Out:
#                                  Property       Date  \
# 0    1601 MADISON COURT PALATKA, FL 32177 2017-01-01
# 1    1601 MADISON COURT PALATKA, FL 32177 2017-01-04
# 2    1601 MADISON COURT PALATKA, FL 32177 2017-01-11
# 3    1601 MADISON COURT PALATKA, FL 32177 2017-01-26
# 4    1601 MADISON COURT PALATKA, FL 32177 2017-02-01
# 5    1601 MADISON COURT PALATKA, FL 32177 2017-02-01
# 6    1601 MADISON COURT PALATKA, FL 32177 2017-02-08
# 7    1601 MADISON COURT PALATKA, FL 32177 2017-02-08
# 8    1601 MADISON COURT PALATKA, FL 32177 2017-02-13
# 9    1601 MADISON COURT PALATKA, FL 32177 2017-02-21
# 10   1601 MADISON COURT PALATKA, FL 32177 2017-03-01
# 11   1601 MADISON COURT PALATKA, FL 32177 2017-03-01
# 12   1601 MADISON COURT PALATKA, FL 32177 2017-03-13
# 13   1601 MADISON COURT PALATKA, FL 32177 2017-03-17
# 14   1601 MADISON COURT PALATKA, FL 32177 2017-04-01
# 15   1601 MADISON COURT PALATKA, FL 32177 2017-04-03
# 16   1601 MADISON COURT PALATKA, FL 32177 2017-04-12
# 17   1601 MADISON COURT PALATKA, FL 32177 2017-04-28
# 18   1601 MADISON COURT PALATKA, FL 32177 2017-05-01
# 19   1601 MADISON COURT PALATKA, FL 32177 2017-05-01
# 20   1601 MADISON COURT PALATKA, FL 32177 2017-05-11
# 21   1601 MADISON COURT PALATKA, FL 32177 2017-05-29
# 22   1601 MADISON COURT PALATKA, FL 32177 2017-06-01
# 23   1601 MADISON COURT PALATKA, FL 32177 2017-06-01
# 24   1601 MADISON COURT PALATKA, FL 32177 2017-06-06
# 25   1601 MADISON COURT PALATKA, FL 32177 2017-06-06
# 26   1601 MADISON COURT PALATKA, FL 32177 2017-06-06
# 27   1601 MADISON COURT PALATKA, FL 32177 2017-06-06
# 28   1601 MADISON COURT PALATKA, FL 32177 2017-06-13
# 29   1601 MADISON COURT PALATKA, FL 32177 2017-06-29
# ..                                    ...        ...
# 588   760 HIBRITEN WAY LAKELAND, FL 33803 2017-08-25
# 589   760 HIBRITEN WAY LAKELAND, FL 33803 2017-08-27
# 590   760 HIBRITEN WAY LAKELAND, FL 33803 2017-08-27
# 591   760 HIBRITEN WAY LAKELAND, FL 33803 2017-08-31
# 592   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 593   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 594   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 595   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 596   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 597   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 598   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 599   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 600   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-01
# 601   760 HIBRITEN WAY LAKELAND, FL 33803 2017-09-08
# 602   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-10
# 603   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-10
# 604   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-10
# 605   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-10
# 606   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 607   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 608   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 609   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 610   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 611   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 612   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 613   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-12
# 614   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-13
# 615   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-13
# 616   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-13
# 617   760 HIBRITEN WAY LAKELAND, FL 33803 2017-10-18
#
#                                    Payee / Payer                     Type  \
# 0                                 MATTHEW TURNER                  Receipt
# 1    Jackson & Johnson Management & Leasing Inc.                    Check
# 2                         NORTH INVESTMENTS, LLC              ACH payment
# 3                                 MATTHEW TURNER           eCheck receipt
# 4    Jackson & Johnson Management & Leasing Inc.                    Check
# 5                                 MATTHEW TURNER                  Receipt
# 6              FIRSTBANK RESIDENTIAL SERVICES CO              ACH payment
# 7    Jackson & Johnson Management & Leasing Inc.                    Check
# 8                         NORTH INVESTMENTS, LLC              ACH payment
# 9                                 MATTHEW TURNER           eCheck receipt
# 10   Jackson & Johnson Management & Leasing Inc.                    Check
# 11                                MATTHEW TURNER                  Receipt
# 12                        NORTH INVESTMENTS, LLC              ACH payment
# 13                                MATTHEW TURNER           eCheck receipt
# 14                                MATTHEW TURNER                  Receipt
# 15   Jackson & Johnson Management & Leasing Inc.                    Check
# 16                        NORTH INVESTMENTS, LLC              ACH payment
# 17                                MATTHEW TURNER           eCheck receipt
# 18   Jackson & Johnson Management & Leasing Inc.                    Check
# 19                                MATTHEW TURNER                  Receipt
# 20                        NORTH INVESTMENTS, LLC              ACH payment
# 21                                MATTHEW TURNER           eCheck receipt
# 22   Jackson & Johnson Management & Leasing Inc.                    Check
# 23                                MATTHEW TURNER                  Receipt
# 24             FIRSTBANK RESIDENTIAL SERVICES CO              ACH payment
# 25             FIRSTBANK RESIDENTIAL SERVICES CO              ACH payment
# 26   Jackson & Johnson Management & Leasing Inc.                    Check
# 27   Jackson & Johnson Management & Leasing Inc.                    Check
# 28                        NORTH INVESTMENTS, LLC              ACH payment
# 29                                MATTHEW TURNER           eCheck receipt
# ..                                           ...                      ...
# 588  Jackson & Johnson Management & Leasing Inc.                    Check
# 589                                    JAMIE DEA           eCheck receipt
# 590                                    JAMIE DEA           eCheck receipt
# 591  Jackson & Johnson Management & Leasing Inc.                    Check
# 592  Jackson & Johnson Management & Leasing Inc.                    Check
# 593  Jackson & Johnson Management & Leasing Inc.                    Check
# 594            FIRSTBANK RESIDENTIAL SERVICES CO              ACH payment
# 595            FIRSTBANK RESIDENTIAL SERVICES CO              ACH payment
# 596  Jackson & Johnson Management & Leasing Inc.                    Check
# 597  Jackson & Johnson Management & Leasing Inc.                    Check
# 598                                    JAMIE DEA                  Receipt
# 599                                    JAMIE DEA                  Receipt
# 600                                    JAMIE DEA                  Receipt
# 601                  GEORGE & JESSICA RODRIGUIEZ              ACH payment
# 602                                    JAMIE DEA  Reversed eCheck receipt
# 603                                    JAMIE DEA  Reversed eCheck receipt
# 604                                    JAMIE DEA  Reversed eCheck receipt
# 605                                    JAMIE DEA  Reversed eCheck receipt
# 606                                    JAMIE DEA          Reverse Receipt
# 607                                    JAMIE DEA          Reverse Receipt
# 608                                    JAMIE DEA          Reverse Receipt
# 609                                    JAMIE DEA          Reverse Receipt
# 610                                    JAMIE DEA           eCheck receipt
# 611                                    JAMIE DEA           eCheck receipt
# 612                                    JAMIE DEA           eCheck receipt
# 613                                    JAMIE DEA           eCheck receipt
# 614  Jackson & Johnson Management & Leasing Inc.                    Check
# 615  Jackson & Johnson Management & Leasing Inc.                    Check
# 616  Jackson & Johnson Management & Leasing Inc.                    Check
# 617                  GEORGE & JESSICA RODRIGUIEZ              ACH payment
#
#      Reference  Debit_x  Credit_x  Balance_x  \
# 0          NaN      NaN   1425.00  -42134.23
# 1        77621      NaN    114.00  -42134.23
# 2          NaN      NaN   1311.00  -42134.23
# 3    A7BF-5FEC      NaN   1525.00  -43659.23
# 4        77812      NaN    122.00  -42134.23
# 5          NaN      NaN   1525.00  -42134.23
# 6          NaN      NaN    243.50  -42134.23
# 7        77905      NaN     24.35  -42134.23
# 8          NaN      NaN   1135.15  -42134.23
# 9    E741-D52F      NaN   1525.00  -43659.23
# 10       77997      NaN    122.00  -42134.23
# 11         NaN      NaN   1525.00  -42134.23
# 12         NaN      NaN   1403.00  -42134.23
# 13   7739-101E      NaN   1525.00  -43659.23
# 14         NaN      NaN   1525.00  -42134.23
# 15       78191      NaN    122.00  -42134.23
# 16         NaN      NaN   1403.00  -42134.23
# 17   F24A-0DFA      NaN   1525.00  -43659.23
# 18       78378      NaN    122.00  -42134.23
# 19         NaN      NaN   1525.00  -42134.23
# 20         NaN      NaN   1403.00  -42134.23
# 21   A578-64A4      NaN   1525.00  -43659.23
# 22       78546      NaN    122.00  -42134.23
# 23         NaN      NaN   1525.00  -42134.23
# 24         NaN      NaN    206.25  -42134.23
# 25         NaN      NaN    225.00  -41927.98
# 26       78597      NaN     22.50  -42113.60
# 27       78597      NaN     20.63  -42134.23
# 28         NaN      NaN    928.62  -42134.23
# 29   E996-8C6E      NaN   1279.03  -43413.26
# ..         ...      ...       ...        ...
# 588      79222      NaN    119.50  -42134.23
# 589  CAE3-96EE      NaN   1207.50  -43381.73
# 590  CAE3-96EE      NaN     40.00  -42174.23
# 591      79243      NaN     40.00  -42134.23
# 592      79247      NaN     95.60  -42134.23
# 593      79254      NaN     12.50  -42134.23
# 594        NaN      NaN    195.60  -41688.75
# 595        NaN      NaN    445.48  -42134.23
# 596      79271      NaN     19.56  -42089.68
# 597      79271      NaN     44.55  -42134.23
# 598        NaN      NaN   1195.00  -42134.23
# 599        NaN      NaN      3.00  -42134.23
# 600        NaN      NaN      9.50  -42134.23
# 601        NaN      NaN   1583.61  -42134.23
# 602  DA77-CC08      NaN   1195.00  -43329.23
# 603  DA77-CC08      NaN    119.50  -43461.23
# 604  DA77-CC08      NaN      3.00  -43332.23
# 605  DA77-CC08      NaN      9.50  -43341.73
# 606        NaN      NaN   1195.00  -42002.23
# 607        NaN      NaN      3.00  -42005.23
# 608        NaN      NaN      9.50  -42014.73
# 609        NaN      NaN    119.50  -42134.23
# 610  EA9C-55B8      NaN   1195.00  -43329.23
# 611  EA9C-55B8      NaN    119.50  -43461.23
# 612  EA9C-55B8      NaN      3.00  -43332.23
# 613  EA9C-55B8      NaN      9.50  -43341.73
# 614      79678      NaN     95.60  -42134.23
# 615      79679      NaN    119.50  -42134.23
# 616      79684      NaN     12.50  -42134.23
# 617        NaN      NaN   1099.40  -42134.23
#
#                                          Description_x  \
# 0                                                  NaN
# 1                                                  NaN
# 2                            Owner payment for 01/2017
# 3                                       Online Payment
# 4                                                  NaN
# 5                                                  NaN
# 6    As you may know, we had some really strong win...
# 7                                  Markup for FL-20893
# 8                            Owner payment for 02/2017
# 9                                       Online Payment
# 10                                                 NaN
# 11                                                 NaN
# 12                           Owner payment for 03/2017
# 13                                      Online Payment
# 14                                                 NaN
# 15                                                 NaN
# 16                           Owner payment for 04/2017
# 17                                      Online Payment
# 18                                                 NaN
# 19                                                 NaN
# 20                           Owner payment for 05/2017
# 21                                      Online Payment
# 22                                                 NaN
# 23                                                 NaN
# 24   Can someone from Firstbank please schedule a C...
# 25   Central air\r\n\r\nIt has got warmer and this ...
# 26                                 Markup for FL-22842
# 27                                 Markup for FL-22891
# 28                           Owner payment for 06/2017
# 29                                      Online Payment
# ..                                                 ...
# 588                                                NaN
# 589                                     Online Payment
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
# 594  dishwasher is leaking\r\nGarage door opener is...
# 595  dishwasher is leaking\r\nGarage door opener is...
# 596                                Markup for FL-25264
# 597                                Markup for FL-25264
# 598                                                NaN
# 599                                                NaN
# 600                                                NaN
# 601                          Owner payment for 09/2017
# 602                                    Reversed by NSF
# 603                                    Reversed by NSF
# 604                                    Reversed by NSF
# 605                                    Reversed by NSF
# 606      NSF reversal receipt for Reference #DA77-CC08
# 607      NSF reversal receipt for Reference #DA77-CC08
# 608      NSF reversal receipt for Reference #DA77-CC08
# 609      NSF reversal receipt for Reference #DA77-CC08
# 610                                              43009
# 611                              Late Fee for Oct 2017
# 612                                              43009
# 613          October 2017 - Tenant Liability Insurance
# 614                                                NaN
# 615                                                NaN
# 616                                                NaN
# 617                          Owner payment for 10/2017
#
#                           GL Account_x  Debit_y  Credit_y  Balance_y  \
# 0                 4001 - RENTAL INCOME  1425.00       NaN  -40709.23
# 1                     1001 - MAIN CASH   114.00       NaN  -42020.23
# 2                     1001 - MAIN CASH  1311.00       NaN  -40823.23
# 3            1005 - TENANT PREPAYMENTS  1525.00       NaN  -42134.23
# 4                     1001 - MAIN CASH   122.00       NaN  -42012.23
# 5                 4001 - RENTAL INCOME  1525.00       NaN  -40609.23
# 6                     1001 - MAIN CASH   243.50       NaN  -41890.73
# 7                     1001 - MAIN CASH    24.35       NaN  -42109.88
# 8                     1001 - MAIN CASH  1135.15       NaN  -40999.08
# 9            1005 - TENANT PREPAYMENTS  1525.00       NaN  -42134.23
# 10                    1001 - MAIN CASH   122.00       NaN  -42012.23
# 11                4001 - RENTAL INCOME  1525.00       NaN  -40609.23
# 12                    1001 - MAIN CASH  1403.00       NaN  -40731.23
# 13           1005 - TENANT PREPAYMENTS  1525.00       NaN  -42134.23
# 14                4001 - RENTAL INCOME  1525.00       NaN  -40609.23
# 15                    1001 - MAIN CASH   122.00       NaN  -42012.23
# 16                    1001 - MAIN CASH  1403.00       NaN  -40731.23
# 17           1005 - TENANT PREPAYMENTS  1525.00       NaN  -42134.23
# 18                    1001 - MAIN CASH   122.00       NaN  -42012.23
# 19                4001 - RENTAL INCOME  1525.00       NaN  -40609.23
# 20                    1001 - MAIN CASH  1403.00       NaN  -40731.23
# 21           1005 - TENANT PREPAYMENTS  1525.00       NaN  -42134.23
# 22                    1001 - MAIN CASH   122.00       NaN  -42012.23
# 23                4001 - RENTAL INCOME  1525.00       NaN  -40609.23
# 24                    1001 - MAIN CASH   206.25       NaN  -41702.98
# 25                    1001 - MAIN CASH   225.00       NaN  -41909.23
# 26                    1001 - MAIN CASH    22.50       NaN  -42111.73
# 27                    1001 - MAIN CASH    20.63       NaN  -42091.10
# 28                    1001 - MAIN CASH   928.62       NaN  -41205.61
# 29           1005 - TENANT PREPAYMENTS  1279.03       NaN  -42134.23
# ..                                 ...      ...       ...        ...
# 588                   1001 - MAIN CASH   119.50       NaN  -42014.73
# 589          1005 - TENANT PREPAYMENTS  1207.50       NaN  -42134.23
# 590                     4004 - NSF FEE    40.00       NaN  -43341.73
# 591                   1001 - MAIN CASH    40.00       NaN  -42094.23
# 592                   1001 - MAIN CASH    95.60       NaN  -42038.63
# 593                   1001 - MAIN CASH    12.50       NaN  -42121.73
# 594                   1001 - MAIN CASH   195.60       NaN  -41938.63
# 595                   1001 - MAIN CASH   445.48       NaN  -41493.15
# 596                   1001 - MAIN CASH    19.56       NaN  -42114.67
# 597                   1001 - MAIN CASH    44.55       NaN  -42070.12
# 598               4001 - RENTAL INCOME  1195.00       NaN  -40939.23
# 599  9001 - Tenant Liability Insurance     3.00       NaN  -42131.23
# 600  9001 - Tenant Liability Insurance     9.50       NaN  -42124.73
# 601                   1001 - MAIN CASH  1583.61       NaN  -40550.62
# 602               4001 - RENTAL INCOME  1195.00       NaN  -42266.23
# 603                   4003 - LATE FEES   119.50       NaN  -42134.23
# 604  9001 - Tenant Liability Insurance     3.00       NaN  -42263.23
# 605  9001 - Tenant Liability Insurance     9.50       NaN  -42253.73
# 606                   1001 - MAIN CASH  1195.00       NaN  -40939.23
# 607                   1001 - MAIN CASH     3.00       NaN  -40936.23
# 608                   1001 - MAIN CASH     9.50       NaN  -40926.73
# 609                   1001 - MAIN CASH   119.50       NaN  -40807.23
# 610               4001 - RENTAL INCOME  1195.00       NaN  -42266.23
# 611                   4003 - LATE FEES   119.50       NaN  -42134.23
# 612  9001 - Tenant Liability Insurance     3.00       NaN  -42263.23
# 613  9001 - Tenant Liability Insurance     9.50       NaN  -42253.73
# 614                   1001 - MAIN CASH    95.60       NaN  -42038.63
# 615                   1001 - MAIN CASH   119.50       NaN  -42014.73
# 616                   1001 - MAIN CASH    12.50       NaN  -42121.73
# 617                   1001 - MAIN CASH  1099.40       NaN  -41034.83
#
#                                          Description_y  \
# 0                                                  NaN
# 1                          MANAGEMENT FEE  for 01/2017
# 2                                                  NaN
# 3                                       Online Payment
# 4                          MANAGEMENT FEE  for 02/2017
# 5                                                  NaN
# 6    REPLACE SCREEN; INSTALL GUTTER CLIPS; REATTACH...
# 7    Markup: REPLACE SCREEN; INSTALL GUTTER CLIPS; ...
# 8                                                  NaN
# 9                                       Online Payment
# 10                         MANAGEMENT FEE  for 03/2017
# 11                                                 NaN
# 12                                                 NaN
# 13                                      Online Payment
# 14                                                 NaN
# 15                         MANAGEMENT FEE  for 04/2017
# 16                                                 NaN
# 17                                      Online Payment
# 18                         MANAGEMENT FEE  for 05/2017
# 19                                                 NaN
# 20                                                 NaN
# 21                                      Online Payment
# 22                         MANAGEMENT FEE  for 06/2017
# 23                                                 NaN
# 24                               REPLACE RUN CAPACITOR
# 25   FOUND REFRIGERANT LEAKING FROM SVC VALVE. REPL...
# 26   Markup: FOUND REFRIGERANT LEAKING FROM SVC VAL...
# 27                       Markup: REPLACE RUN CAPACITOR
# 28                                                 NaN
# 29                                      Online Payment
# ..                                                 ...
# 588                              LATE FEE  for 08/2017
# 589                                     Online Payment
# 590                                                NaN
# 591                                NSF FEE for 08/2017
# 592                        MANAGEMENT FEE  for 09/2017
# 593             Tenant Liability Insurance for 09/2017
# 594               REPLACE DISHWASHER WATER SUPPLY LINE
# 595                                 REPAIR GARAGE DOOR
# 596       Markup: REPLACE DISHWASHER WATER SUPPLY LINE
# 597                         Markup: REPAIR GARAGE DOOR
# 598                                                NaN
# 599                                                NaN
# 600                                                NaN
# 601                                                NaN
# 602                                              43009
# 603                              Late Fee for Oct 2017
# 604                                              43009
# 605          October 2017 - Tenant Liability Insurance
# 606      NSF reversal receipt for Reference #DA77-CC08
# 607      NSF reversal receipt for Reference #DA77-CC08
# 608      NSF reversal receipt for Reference #DA77-CC08
# 609      NSF reversal receipt for Reference #DA77-CC08
# 610                                              43009
# 611                              Late Fee for Oct 2017
# 612                                              43009
# 613          October 2017 - Tenant Liability Insurance
# 614                        MANAGEMENT FEE  for 10/2017
# 615                              LATE FEE  for 10/2017
# 616             Tenant Liability Insurance for 10/2017
# 617                                                NaN
#
#                             GL Account_y
# 0              1005 - TENANT PREPAYMENTS
# 1                  8000 - MANAGEMENT FEE
# 2    3002 - EQUITY DISTRIBUTION TO OWNER
# 3                       1001 - MAIN CASH
# 4                  8000 - MANAGEMENT FEE
# 5              1005 - TENANT PREPAYMENTS
# 6            6000 - BUILDING MAINTENANCE
# 7               6090 - Work Order Markup
# 8    3002 - EQUITY DISTRIBUTION TO OWNER
# 9                       1001 - MAIN CASH
# 10                 8000 - MANAGEMENT FEE
# 11             1005 - TENANT PREPAYMENTS
# 12   3002 - EQUITY DISTRIBUTION TO OWNER
# 13                      1001 - MAIN CASH
# 14             1005 - TENANT PREPAYMENTS
# 15                 8000 - MANAGEMENT FEE
# 16   3002 - EQUITY DISTRIBUTION TO OWNER
# 17                      1001 - MAIN CASH
# 18                 8000 - MANAGEMENT FEE
# 19             1005 - TENANT PREPAYMENTS
# 20   3002 - EQUITY DISTRIBUTION TO OWNER
# 21                      1001 - MAIN CASH
# 22                 8000 - MANAGEMENT FEE
# 23             1005 - TENANT PREPAYMENTS
# 24            6011 - A/C- FURNACE REPAIR
# 25            6011 - A/C- FURNACE REPAIR
# 26              6090 - Work Order Markup
# 27              6090 - Work Order Markup
# 28   3002 - EQUITY DISTRIBUTION TO OWNER
# 29                      1001 - MAIN CASH
# ..                                   ...
# 588                     4003 - LATE FEES
# 589                     1001 - MAIN CASH
# 590                     1001 - MAIN CASH
# 591                       4004 - NSF FEE
# 592                8000 - MANAGEMENT FEE
# 593    9001 - Tenant Liability Insurance
# 594              6012 - APPLIANCE REPAIR
# 595            6013 - GARAGE DOOR REPAIR
# 596             6090 - Work Order Markup
# 597             6090 - Work Order Markup
# 598            1005 - TENANT PREPAYMENTS
# 599            1005 - TENANT PREPAYMENTS
# 600            1005 - TENANT PREPAYMENTS
# 601  3002 - EQUITY DISTRIBUTION TO OWNER
# 602                     1001 - MAIN CASH
# 603                     1001 - MAIN CASH
# 604                     1001 - MAIN CASH
# 605                     1001 - MAIN CASH
# 606                 4001 - RENTAL INCOME
# 607    9001 - Tenant Liability Insurance
# 608    9001 - Tenant Liability Insurance
# 609                     4003 - LATE FEES
# 610                     1001 - MAIN CASH
# 611                     1001 - MAIN CASH
# 612                     1001 - MAIN CASH
# 613                     1001 - MAIN CASH
# 614                8000 - MANAGEMENT FEE
# 615                     4003 - LATE FEES
# 616    9001 - Tenant Liability Insurance
# 617  3002 - EQUITY DISTRIBUTION TO OWNER
#
# [618 rows x 15 columns]

# %%
# If the desired output is a single list containing all the matching debits and credits then we concatinate
matched=pd.concat([dfs_credit,dfs_debit])

# %%
# We take a set difference of all debits and matched debits(subtract latter from the former). This gives us the unmatched debits: 
# A left-join of all debits with matched debits such that the matched debit is null.
# This is normaly straightforward in SQL(see ref #1) but we can do it in two steps in Python.
# First left-join the two tables such that all rows from the left table (dfs_all_debit) is present in the interim result.
# This means that some of the matching rows in the right table (dfs_debit) are going to be null
#
dfs_debit_leftj=dfs_all_debit.merge(dfs_debit, right_on=('Property','Date','Payee / Payer','Type','Reference','Debit_x'), left_on=('Property','Date','Payee / Payer','Type','Reference','Debit'), how='left')
# In the second step we simply select those rows with the right debit value null.
unmatched_debit=dfs_debit_leftj[dfs_debit_leftj['Debit_x'].isnull()]

# %%
#Repeat above step for credits
dfs_credit_leftj=dfs_all_credit.merge(dfs_credit, right_on=['Property','Date','Payee / Payer','Type','Reference','Credit_x'], left_on=['Property','Date','Payee / Payer','Type','Reference','Credit'], how='left')
unmatched_credit=dfs_credit_leftj[dfs_credit_leftj['Credit_x'].isnull()]
unmatched_credit
# Out:
#                              Property       Date Payee / Payer     Type  \
# 125  211 DAVENTRY DR DEBARY, FL 32713 2017-02-27   KARL KOSMOS  Receipt
# 132  211 DAVENTRY DR DEBARY, FL 32713 2017-03-29   KARL KOSMOS  Receipt
# 133  211 DAVENTRY DR DEBARY, FL 32713 2017-03-29   KARL KOSMOS  Receipt
# 135  211 DAVENTRY DR DEBARY, FL 32713 2017-04-03   KARL KOSMOS  Receipt
# 136  211 DAVENTRY DR DEBARY, FL 32713 2017-04-03   KARL KOSMOS  Receipt
# 169  211 DAVENTRY DR DEBARY, FL 32713 2017-07-01   KARL KOSMOS  Receipt
# 170  211 DAVENTRY DR DEBARY, FL 32713 2017-07-01   KARL KOSMOS  Receipt
# 176  211 DAVENTRY DR DEBARY, FL 32713 2017-08-01   KARL KOSMOS  Receipt
# 177  211 DAVENTRY DR DEBARY, FL 32713 2017-08-01   KARL KOSMOS  Receipt
# 183  211 DAVENTRY DR DEBARY, FL 32713 2017-09-01   KARL KOSMOS  Receipt
# 184  211 DAVENTRY DR DEBARY, FL 32713 2017-09-01   KARL KOSMOS  Receipt
# 189  211 DAVENTRY DR DEBARY, FL 32713 2017-10-01   KARL KOSMOS  Receipt
# 190  211 DAVENTRY DR DEBARY, FL 32713 2017-10-01   KARL KOSMOS  Receipt
# 508   7007 LAKE AVE ORLANDO, FL 32801 2017-10-19    GREG POACH  Receipt
# 509   7007 LAKE AVE ORLANDO, FL 32801 2017-10-19    GREG POACH  Receipt
# 510   7007 LAKE AVE ORLANDO, FL 32801 2017-10-19    GREG POACH  Receipt
#
#     Reference  Debit   Credit   Balance                           Description  \
# 125       NaN    NaN   158.00 -42104.23                                 42767
# 132       NaN    NaN    33.00 -42104.23                                 42795
# 133       NaN    NaN    30.00 -42134.23                                 42795
# 135       NaN    NaN    33.00 -42104.23                                 42826
# 136       NaN    NaN    30.00 -42134.23                                 42826
# 169       NaN    NaN    33.00 -42104.23                                 42917
# 170       NaN    NaN    30.00 -42134.23                                 42917
# 176       NaN    NaN    33.00 -42104.23                                 42948
# 177       NaN    NaN    30.00 -42134.23                                 42948
# 183       NaN    NaN    33.00 -42104.23                                 42979
# 184       NaN    NaN    30.00 -42134.23                                 42979
# 189       NaN    NaN    33.00 -42104.23                                 43009
# 190       NaN    NaN    30.00 -42134.23                                 43009
# 508       NaN    NaN   138.74 -42272.97    Paid Charge at Move Out: June 2017
# 509       NaN    NaN  1409.00 -43681.97    Paid Charge at Move Out: July 2017
# 510       NaN    NaN   591.26 -44273.23  Paid Charge at Move Out: August 2017
#
#                GL Account  Debit_x  Credit_x  Balance_x Description_x  \
# 125  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 132  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 133   6015 - PEST CONTROL      NaN       NaN        NaN           NaN
# 135  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 136   6015 - PEST CONTROL      NaN       NaN        NaN           NaN
# 169  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 170   6015 - PEST CONTROL      NaN       NaN        NaN           NaN
# 176  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 177   6015 - PEST CONTROL      NaN       NaN        NaN           NaN
# 183  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 184   6015 - PEST CONTROL      NaN       NaN        NaN           NaN
# 189  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 190   6015 - PEST CONTROL      NaN       NaN        NaN           NaN
# 508  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 509  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
# 510  4001 - RENTAL INCOME      NaN       NaN        NaN           NaN
#
#     GL Account_x  Debit_y  Credit_y  Balance_y Description_y GL Account_y
# 125          NaN      NaN       NaN        NaN           NaN          NaN
# 132          NaN      NaN       NaN        NaN           NaN          NaN
# 133          NaN      NaN       NaN        NaN           NaN          NaN
# 135          NaN      NaN       NaN        NaN           NaN          NaN
# 136          NaN      NaN       NaN        NaN           NaN          NaN
# 169          NaN      NaN       NaN        NaN           NaN          NaN
# 170          NaN      NaN       NaN        NaN           NaN          NaN
# 176          NaN      NaN       NaN        NaN           NaN          NaN
# 177          NaN      NaN       NaN        NaN           NaN          NaN
# 183          NaN      NaN       NaN        NaN           NaN          NaN
# 184          NaN      NaN       NaN        NaN           NaN          NaN
# 189          NaN      NaN       NaN        NaN           NaN          NaN
# 190          NaN      NaN       NaN        NaN           NaN          NaN
# 508          NaN      NaN       NaN        NaN           NaN          NaN
# 509          NaN      NaN       NaN        NaN           NaN          NaN
# 510          NaN      NaN       NaN        NaN           NaN          NaN

# %%
# Write matched records to excel file
writer = pd.ExcelWriter('Matched.xlsx')
matched[matched.columns[0:10]].to_excel(writer,'Sheet1')
writer.save()

# Write unmatched records to excel file
writer = pd.ExcelWriter('UnMatched_Credits.xlsx')
unmatched_credit[unmatched_credit.columns[0:10]].to_excel(writer,'Sheet1')
writer.save()
writer = pd.ExcelWriter('UnMatched_Debits.xlsx')
unmatched_debit[unmatched_debit.columns[0:10]].to_excel(writer,'Sheet1')
writer.save()
